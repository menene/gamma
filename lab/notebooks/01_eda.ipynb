# %% [markdown]
# # Exploracion del Maestro de Materiales\n\nNotebook para explorar y entender la estructura del maestro de materiales en `silver.maestro`.\n- Distribucion de categorias\n- Longitud de descripciones\n- Materiales duplicados potenciales
